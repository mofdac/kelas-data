# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Pemakaian Python

# %% [markdown]
# ### Games

# %% [markdown]
# <a href="https://github.com/grantjenks/free-python-games" target="_blank">Games</a>

# %%
# !pip install freegames
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\virtual_env\python38\scripts\python.exe -m pip install --upgrade pip' command.

# %%
"""Bounce, a simple animation demo.

Exercises

1. Make the ball speed up and down.
2. Change how the ball bounces when it hits a wall.
3. Make the ball leave a trail.
4. Change the ball color based on position.
   Hint: colormode(255); color(0, 100, 200)

"""

from random import *
from turtle import *
from freegames import vector

def value():
    "Randomly generate value between (-5, -3) or (3, 5)."
    return (3 + random() * 2) * choice([1, -1])

ball = vector(0, 0)
aim = vector(value(), value())

def draw():
    "Move ball and draw game."
    ball.move(aim)

    x = ball.x
    y = ball.y

    if x < -200 or x > 200:
        aim.x = -aim.x

    if y < -200 or y > 200:
        aim.y = -aim.y

    clear()
    goto(x, y)
    dot(10)

    ontimer(draw, 50)

setup(420, 420, 370, 0)
hideturtle()
tracer(False)
up()
draw()
done()

# %% [markdown]
# ### Data Science

# %% [markdown]
# <a href="http://localhost:8888/notebooks/python/python%20I/Keras_Mnist.ipynb" target="_blank"> mnist implementation</a>

# %% [markdown]
# <a href="https://github.com/aaronpenne/data_visualization" target="_blank"> various visualisation</a>

# %% [markdown]
# ## Kenapa Python
#
#
# *   Mudah Digunakan
# *   Simple dan mudah dipahami
# * Open Source sehingga memiliki library yang sangat lengkap

# %% [markdown]
# ## Contoh Penggunaan Python
# * Youtube
# * DropBox
# * Raspberry Pi
# * NASA
# * HAckintosh

# %% [markdown]
# ## HIGH LEVEL PROGRAMMING LANGUAGE
# * Tidak Dieksekusi langsung di CPU, membutuhkan translator.
# * Mudah di Implementasikan (berupa script programming, bukan binary)
# * portable, Tidak Perlu di compile dan platform independent.

# %% [markdown]
# ## Menjalankan Python
# * Interactive Mode
#   * Shell / terminal / cmd
#   * Jupyter notebook
#   * GUI apps, etc
# * Script Mode
#   * Menajalan dari script *.py

# %% [markdown]
# # Konsep Dasar Pemrograman

# %% [markdown]
# ## Program
# Sebuah solusi yang di implementasikan dengan bahasa pemrogaman tertentu untuk menyelesaikan
# permasalahan komputasi
# ## Algoritma
# Solusi yang di desain untuk permasalahan tertentu
# Memiliki urutan tertentu untuk dengan pola tertentu untuk mejalankan instruksi.

# %% [markdown]
# ## Komponen yang harus (biasanya) ada
# * Input
#
#   umumnya dari keyboard, bisa juga dari microphone, camera ataupun bentuk input lainnya
# * Output
#
#   Layar, object, memory
# * Operations
#
#   Operasi seperti penjumlahan, bagi, kali, pembanding dll
# * Control Structure
#
#   Structure dari program itu sendiri
# * Flow execution
#
#   Alur penyelesaian masalah / exekusi

# %% [markdown]
# # **PYTHON**

# %% [markdown]
# ![PYTHON.png](data:image/png;base64,...)

# %% [markdown]
# ## Object vs Variable
# **Object**
# * Elemen utama python
# * Bagian dari memory yang menyimpan data dengan type tertentu
# * adalah data dari object itu sendiri
#
# **Variable**
#
# Nama yang di hubungkan dengan object
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Variable name python
# Aturan dasar penamaan variable
# * a-zA-Z0-9_
# * Case sensitive
# * Tidak bolehdimulai dengan angka
# * Tidak boleh sama dengan nama fungsi bawaan python
#
# Untuk aturan terakhir, berbeda dengan bahasa pemrogaman lain, nama variable bawaan python bisa didevinisikan ulang/dipakai, akan tetapi kalau dilakukan tanpa sengaja bisanaya membuat program berjalan tidak sesuai yang di inginkan.

# %% [markdown]
# ## Primitive data type python
# Secara primitive/dasar type data dalam python dapat dibedakan menjadi dua
# *  Atomic
#   * Mewakili satu object yang tidak bs dibagi bagi
#   * Int, float, boolean
# * Colletive
#
#   Bisa dibagi bagi
#   * String ( “makan” = m,a,k,a,n )
#   * List
#   * Tuple
#   * Dictionary
#
# Dalam python String selalu diperlakukan seperti list

# %% [markdown]
# ## Logical operator
# ada tiga logical operator
# * AND
# * OR
# * NOT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *credit : Erik Sacre, Bases de Datos*

# %% [markdown]
# ## Comparison operator
#  * ==
#  * *>*
#  * <
#  * <=
#  * *>=*
#  * <>
#
#
# **Bagaimana dengan “=“ …. ?**

# %%
1==2
# Out:
# False

# %%
a=1 ## contoh assigment

# %% [markdown]
# ## Print statement

# %% [markdown]
# * Sangat peting dalam semua bahasa pemrograman
# * Menampilkan output baik itu
#   * Hasil
#   * Debug
#   * Valriable
#   * Object
#   * dll
# * debuging
#
#   Kemampuan debugging menggunakan "print" ini sangat penting

# %% [markdown]
# ``print(string)``

# %%
print("hello world")
# Out:
# hello world

# %%
a = 3
if (a==3):
  print("masuk ke a = 3")
else :
  print("masuk else")
# Out:
# masuk ke a = 3

# %%
a = "object string"
print(a)
# Out:
# object string

# %% [markdown]
# ## Comment

# %% [markdown]
# Berguna untuk memberi informasi tambahan:
# * Dokumentasi
# * Informasi variable
# * Dll
#
# ``# comement setelah tanda #``

# %% [markdown]
# **Comment SANGAT PENTING**
#
# Untuk memperjelas code sehingga saat dibaca tidak perlu membaca dari awal

# %% [markdown]
# ### Python strict rule
# **INDENTATION**

# %% [markdown]
# ## Arithmetic operation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 20
a
# Out:
# 20

# %%
a + 2
# Out:
# 22

# %%
a - 2
# Out:
# 18

# %%
a*2
# Out:
# 40

# %%
a//3 # berapa banyak a bisa dibagi 3, tanpa koma
# Out:
# 6

# %%
a/3
# Out:
# 6.666666666666667

# %%
a%3 # sisa dari a dibagi 3 yang tidak habis
# Out:
# 2

# %%
a ** 2 # pangkat
# Out:
# 400

# %% [markdown]
# ## Standar input dan output

# %% [markdown]
#  **Input**
#  * Mendapatkan inputan dari standar input seperti keyboard
#  * Syntax : input() atau input(“masukan nomor”)
#  * Bisa dibatasi jenis type datanya….

# %% [markdown]
# ``input()``
#
# `` input("masukan nomor")``

# %%
input()
# Out:
# oke
# 'oke'

# %%
input("masukan nomor : ")
# Out:
# masukan nomor : 2314
# '2314'

# %%
int(input("masukan nomor : "))
# Out:
# masukan nomor : 123
# 123

# %%
int(input("masukan nomor : "))
# Out:
# masukan nomor : bukan nomor
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-a02fe9702abc> in <module>()
# ----> 1 int(input("masukan nomor : "))
#
# ValueError: invalid literal for int() with base 10: 'bukan nomor'

# %% [markdown]
# **Output**
#
# Menampilkan informasi atau hasil
#
# ``print(“hasil”)``
#
# ``print("hasil sesuatu : " + "123" )``

# %%
print("hasil " + "123")
# Out:
# hasil 123

# %%
print("hasil " + 123) # error string harus dengan string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-6c0aedc723b1> in <module>()
# ----> 1 print("hasil " + 123) # error string harus dengan string
#
# TypeError: must be str, not int

# %% [markdown]
# ## Fungsi dasar python

# %% [markdown]
# ## If statement
# ``If (condition):``
#
# ``  statement``
#
# ``else:``
#
# ``  statement``

# %%
a = 1
b = 1
if (a == b): 
  print(a + b)
# Out:
# 2

# %% [markdown]
# **Bagaimana dengan else if …?**

# %% [markdown]
# ### While statement
# Harus ada **FALSE** condition

# %%
a = 0 
while (a <= 5): 
  print(a) 
  a += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### For statement

# %%
fruits = ["apple", "banana", "cherry"] 
for x in fruits: 
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# For untuk dictionary

# %%
for item in  thisDict.items() : 
  print(item)
# Out:
# ('brand', 'Ford')
# ('model', 'Mustang')
# ('year', 1964)

# %%
for key, value in thisDict.items(): 
  print(key) 
  print(value)
# Out:
# brand
# Ford
# model
# Mustang
# year
# 1964

# %% [markdown]
# ### In statement

# %%
seq = [1,2,3,4,"oke"]

# %%
x = 4
if x in seq: 
  print(str(x) + " exists")
# Out:
# 4 exists

# %%
x = 5
if x not in seq: 
  print(str(x) + " not exists")
# Out:
# 5 not exists

# %% [markdown]
# ### Range statement

# %% [markdown]
# ``range(start,stop,step)``

# %%
for i in range(0,10,2): 
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %% [markdown]
# ## Games

# %% [markdown]
# ## Calculator

# %% [markdown]
# Fungsi:
#
# def nama_fungsi(arguments):
#
#     blok program

# %% [markdown]
# # FINISH

# %% [markdown]
# *jupyter notebook cheat sheet* <a href="https://www.edureka.co/blog/wp-content/uploads/2018/10/Jupyter_Notebook_CheatSheet_Edureka.pdf" target="_blank">**this link**</a>

# %% [markdown]
# *jupyter notebook formating* <a href="https://www.earthdatascience.org/courses/intro-to-earth-data-science/file-formats/use-text-files/format-text-with-markdown-jupyter-notebook/" target="_blank">**this link**</a>
